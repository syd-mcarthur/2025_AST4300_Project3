# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import fits, ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord

# %%
# Age option 3 APOKASC-3 Pinsonneault et al. 2025
#Reading in the table, making sure all the tables have a column named Age in Gyr
# and that every star in the table has an Age
apokasc3raw= Table.read("Pinsonneault2025.txt", format="ascii.cds")
#in this case there were two age columns, one for Red Clump and one for Red Giant Branch so we combine them
ageRC=np.array(apokasc3raw['AgeRC']*(apokasc3raw['EvolState']=='RC'))
rcnans=np.isnan(ageRC) #removing nans from this version of the table.
ageRC[rcnans]=0
ageRGB=np.array(apokasc3raw['AgeRGB']*(apokasc3raw['EvolState']=='RGB'))
rgbnans=np.isnan(ageRGB) #removing nans from this version of the table.
ageRGB[rgbnans]=0
apokasc3raw['Age']=(ageRC+ageRGB)

hasagea3=np.where((apokasc3raw['Age']==apokasc3raw['Age']) & (apokasc3raw['Age']>0.1))
apokasc3=apokasc3raw[hasagea3]
apokasc3
# Out:
# <Table length=12291>
#   KIC    EvolState ESSource ...          2MASS            Age
#                             ...
#  int64      str7     str4   ...          str23          float64
# -------- --------- -------- ... ----------------------- -------
#   893214       RGB     Seis ... 2MASS J19245967+3638183  2.8815
#  1026180        RC     Spec ... 2MASS J19241923+3645378  3.1325
#  1026309       RGB     Seis ... 2MASS J19242636+3643594  0.5842
#  1026452        RC     Seis ... 2MASS J19243452+3647244  2.6495
#  1027110       RGB     Seis ... 2MASS J19250937+3644599  9.0694
#  1027337       RGB     Seis ... 2MASS J19252021+3647118  5.8519
#  1027707       RGB     Seis ... 2MASS J19253846+3646103  1.3052
#  1160655       RGB     Seis ... 2MASS J19232193+3650379  5.7073
#  1160684        RC     Spec ... 2MASS J19232466+3652089   5.307
#      ...       ...      ... ...                     ...     ...
# 12784998        RC     Seis ... 2MASS J19211318+5201390  3.3478
# 12785083        RC     Seis ... 2MASS J19212376+5204593  7.3798
# 12785250       RGB     Spec ... 2MASS J19214766+5205365  4.4587
# 12785401       RGB     Seis ... 2MASS J19221167+5202332 15.6194
# 12833300        RC     Seis ... 2MASS J19171503+5207238  8.1186
# 12884116       RGB     Seis ... 2MASS J19182431+5215519  7.6715
# 12884661        RC     Spec ... 2MASS J19192222+5213103  1.7467
# 12884930        RC     Seis ... 2MASS J19200187+5214588  3.2902
# 12885196       RGB     Seis ... 2MASS J19203926+5214210  4.9813

# %%
#Pick from any of the previous 4 options
agedata= apokasc3

# %%
print('Answer: There are '+str(len(agedata))+' targets with ages in agedata.')
# Out:
# Answer: There are 12291 targets with ages in agedata.

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10

# %%
filename='astraAllStarASPCAP-0.6.0.fits'
tb = fits.open(filename)
data = tb[2].data

# %%
mask_gaia = (data['zgr_plx']>0)

# %%
data_masked=data[mask_gaia]
good = np.where(
    (data_masked['teff'] > 3700) & (data_masked['teff'] < 5300) &
    (data_masked['logg'] > 0.9) & (data_masked['logg'] < 3.3) &
    (data_masked['m_h_atm'] > -2.0) & (data_masked['m_h_atm'] < 0.6) &
    (data_masked['flag_bad'] == False)
)

data_cut = data_masked[good]

# %%
apok3_gaia = apokasc3['GaiaDR3']
dr19_gaia = data_cut['gaia_dr3_source_id']
print(apok3_gaia[:5])
print(dr19_gaia[:5])
# Out:
#       GaiaDR3
# -------------------
# 2050237616959273728
# 2050237174589477888
# 2050236934071312384
# 2050243050104808960
# 2050239201814200192
# [4184200643505162112 4184125807991900928 4184137077986034048
#  4183930438518525184 4689447878791422208]

# %%
lookup = {dr19_gaia[i]: i for i in range(len(dr19_gaia))}

# %%
#Option 3 APOKASC-3 Pinsonneault et al. 2025
intersect, ind_a, ind_b = np.intersect1d(data_cut['gaia_dr3_source_id'], agedata['GaiaDR3'], return_indices=True)

# %%
matched_apok3_rows = []
matched_dr19_indices = []
for row in apokasc3:
    gid = row['GaiaDR3']
    if gid is None or np.isnan(gid):
        continue
    if gid in lookup:
        matched_apok3_rows.append(row)
        matched_dr19_indices.append(lookup[gid])

# %%
apokasc3_matched = Table(rows=matched_apok3_rows, names=apokasc3.colnames)
idx = np.array(matched_dr19_indices)

# %%
print("Matched APOKASC-3 stars:", len(apokasc3_matched))
# Out:
# Matched APOKASC-3 stars: 11028

# %%
fullx = np.dstack([data_cut['teff'][idx], data_cut['logg'][idx], data_cut['m_h_atm'][idx],
    data_cut['alpha_m_atm'][idx], data_cut['c_h'][idx], data_cut['n_h'][idx]])[0]

fully = np.dstack([apokasc3_matched['Age']])[0] #for APOKASC-3 seismic ages

#remove non-finite entries!
mask = np.all(np.isfinite(fullx), axis=1) & np.all(np.isfinite(fully), axis=1)
fullx, fully = fullx[mask], fully[mask]

scaling_x = np.median(fullx, axis=0)
scaling_y = np.median(fully, axis=0)

fullx = fullx / scaling_x
fully = fully / scaling_y
apok3_ids = apokasc3_matched['KIC']

# %%
tenpercent = len(fully) // 10

trainbin = slice(0, -1*tenpercent-1)
testing  = slice(-1*tenpercent, -1)

x_train, y_train = fullx[trainbin], fully[trainbin]
x_test,  y_test  = fullx[testing], fully[testing]

# %% [markdown]
# # Model A

# %%
neurons_per_layer_A = 32
layers_A = 10
iterations_A = 150

# %%
inputs = keras.Input(shape=(6,))
x = inputs
for i in range(layers_A):
    x = keras.layers.Dense(neurons_per_layer_A, activation='relu')(x)

outputs_A = keras.layers.Dense(1)(x)
modelA = keras.Model(inputs=inputs, outputs=outputs_A)
modelA.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 32)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,761 (38.13 KB)
#  Trainable params: 9,761 (38.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelA.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
modelA.fit(x_train, y_train, epochs=iterations_A, validation_data=(x_test, y_test), batch_size=300)
# Out:
# Epoch 1/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0000e+00 - loss: 1.0449 - val_accuracy: 0.0000e+00 - val_loss: 0.6994
# Epoch 2/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.6880 - val_accuracy: 0.0000e+00 - val_loss: 0.5749
# Epoch 3/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.6076 - val_accuracy: 0.0000e+00 - val_loss: 0.5068
# Epoch 4/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5677 - val_accuracy: 0.0000e+00 - val_loss: 0.5558
# Epoch 5/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5777 - val_accuracy: 0.0000e+00 - val_loss: 0.4892
# Epoch 6/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5512 - val_accuracy: 0.0000e+00 - val_loss: 0.4835
# Epoch 7/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5525 - val_accuracy: 0.0000e+00 - val_loss: 0.4799
# Epoch 8/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5427 - val_accuracy: 0.0000e+00 - val_loss: 0.4723
# Epoch 9/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5419 - val_accuracy: 0.0000e+00 - val_loss: 0.4753
# Epoch 10/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5385 - val_accuracy: 0.0000e+00 - val_loss: 0.4682
# Epoch 11/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5410 - val_accuracy: 0.0000e+00 - val_loss: 0.4635
# Epoch 12/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5360 - val_accuracy: 0.0000e+00 - val_loss: 0.4631
# Epoch 13/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5332 - val_accuracy: 0.0000e+00 - val_loss: 0.4856
# Epoch 14/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5442 - val_accuracy: 0.0000e+00 - val_loss: 0.4658
# Epoch 15/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5349 - val_accuracy: 0.0000e+00 - val_loss: 0.4733
# Epoch 16/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5283 - val_accuracy: 0.0000e+00 - val_loss: 0.4647
# Epoch 17/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5264 - val_accuracy: 0.0000e+00 - val_loss: 0.4634
# Epoch 18/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5280 - val_accuracy: 0.0000e+00 - val_loss: 0.4678
# Epoch 19/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5359 - val_accuracy: 0.0000e+00 - val_loss: 0.4527
# Epoch 20/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5240 - val_accuracy: 0.0000e+00 - val_loss: 0.4681
# Epoch 21/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5301 - val_accuracy: 0.0000e+00 - val_loss: 0.4546
# Epoch 22/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5258 - val_accuracy: 0.0000e+00 - val_loss: 0.4665
# Epoch 23/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.5285 - val_accuracy: 0.0000e+00 - val_loss: 0.4648
# Epoch 24/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5369 - val_accuracy: 0.0000e+00 - val_loss: 0.4652
# Epoch 25/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5278 - val_accuracy: 0.0000e+00 - val_loss: 0.4549
# Epoch 26/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5222 - val_accuracy: 0.0000e+00 - val_loss: 0.4571
# Epoch 27/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5347 - val_accuracy: 0.0000e+00 - val_loss: 0.4696
# Epoch 28/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5304 - val_accuracy: 0.0000e+00 - val_loss: 0.4576
# Epoch 29/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5202 - val_accuracy: 0.0000e+00 - val_loss: 0.4553
# Epoch 30/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5174 - val_accuracy: 0.0000e+00 - val_loss: 0.4635
# Epoch 31/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5224 - val_accuracy: 0.0000e+00 - val_loss: 0.4676
# Epoch 32/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5210 - val_accuracy: 0.0000e+00 - val_loss: 0.4571
# Epoch 33/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5127 - val_accuracy: 0.0000e+00 - val_loss: 0.4617
# Epoch 34/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5159 - val_accuracy: 0.0000e+00 - val_loss: 0.4635
# Epoch 35/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5202 - val_accuracy: 0.0000e+00 - val_loss: 0.4501
# Epoch 36/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5117 - val_accuracy: 0.0000e+00 - val_loss: 0.4706
# Epoch 37/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5173 - val_accuracy: 0.0000e+00 - val_loss: 0.4543
# Epoch 38/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5160 - val_accuracy: 0.0000e+00 - val_loss: 0.4686
# Epoch 39/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5252 - val_accuracy: 0.0000e+00 - val_loss: 0.4575
# Epoch 40/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5110 - val_accuracy: 0.0000e+00 - val_loss: 0.4439
# Epoch 41/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5128 - val_accuracy: 0.0000e+00 - val_loss: 0.4676
# Epoch 42/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5149 - val_accuracy: 0.0000e+00 - val_loss: 0.4572
# Epoch 43/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5114 - val_accuracy: 0.0000e+00 - val_loss: 0.4458
# Epoch 44/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5112 - val_accuracy: 0.0000e+00 - val_loss: 0.4604
# Epoch 45/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5144 - val_accuracy: 0.0000e+00 - val_loss: 0.4829
# Epoch 46/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5157 - val_accuracy: 0.0000e+00 - val_loss: 0.4613
# Epoch 47/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5121 - val_accuracy: 0.0000e+00 - val_loss: 0.4454
# Epoch 48/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5050 - val_accuracy: 0.0000e+00 - val_loss: 0.4666
# Epoch 49/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5032 - val_accuracy: 0.0000e+00 - val_loss: 0.4592
# Epoch 50/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5090 - val_accuracy: 0.0000e+00 - val_loss: 0.4463
# Epoch 51/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5101 - val_accuracy: 0.0000e+00 - val_loss: 0.4561
# Epoch 52/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5057 - val_accuracy: 0.0000e+00 - val_loss: 0.4621
# Epoch 53/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5066 - val_accuracy: 0.0000e+00 - val_loss: 0.4712
# Epoch 54/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5018 - val_accuracy: 0.0000e+00 - val_loss: 0.4501
# Epoch 55/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5040 - val_accuracy: 0.0000e+00 - val_loss: 0.4609
# Epoch 56/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5040 - val_accuracy: 0.0000e+00 - val_loss: 0.4523
# Epoch 57/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5166 - val_accuracy: 0.0000e+00 - val_loss: 0.4713
# Epoch 58/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5186 - val_accuracy: 0.0000e+00 - val_loss: 0.4599
# Epoch 59/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5081 - val_accuracy: 0.0000e+00 - val_loss: 0.4578
# Epoch 60/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5066 - val_accuracy: 0.0000e+00 - val_loss: 0.4639
# Epoch 61/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4945 - val_accuracy: 0.0000e+00 - val_loss: 0.4633
# Epoch 62/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5002 - val_accuracy: 0.0000e+00 - val_loss: 0.4606
# Epoch 63/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4981 - val_accuracy: 0.0000e+00 - val_loss: 0.4539
# Epoch 64/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4977 - val_accuracy: 0.0000e+00 - val_loss: 0.4564
# Epoch 65/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4977 - val_accuracy: 0.0000e+00 - val_loss: 0.4701
# Epoch 66/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5124 - val_accuracy: 0.0000e+00 - val_loss: 0.4644
# Epoch 67/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.4992 - val_accuracy: 0.0000e+00 - val_loss: 0.4510
# Epoch 68/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.4968 - val_accuracy: 0.0000e+00 - val_loss: 0.4600
# Epoch 69/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4959 - val_accuracy: 0.0000e+00 - val_loss: 0.4950
# Epoch 70/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5185 - val_accuracy: 0.0000e+00 - val_loss: 0.4697
# Epoch 71/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4997 - val_accuracy: 0.0000e+00 - val_loss: 0.4533
# Epoch 72/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5097 - val_accuracy: 0.0000e+00 - val_loss: 0.4607
# Epoch 73/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5282 - val_accuracy: 0.0000e+00 - val_loss: 0.4739
# Epoch 74/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5267 - val_accuracy: 0.0000e+00 - val_loss: 0.5071
# Epoch 75/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.4692
# Epoch 76/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5147 - val_accuracy: 0.0000e+00 - val_loss: 0.4660
# Epoch 77/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5140 - val_accuracy: 0.0000e+00 - val_loss: 0.4658
# Epoch 78/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5099 - val_accuracy: 0.0000e+00 - val_loss: 0.4572
# Epoch 79/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5126 - val_accuracy: 0.0000e+00 - val_loss: 0.4634
# Epoch 80/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5070 - val_accuracy: 0.0000e+00 - val_loss: 0.4706
# Epoch 81/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5024 - val_accuracy: 0.0000e+00 - val_loss: 0.4588
# Epoch 82/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4955 - val_accuracy: 0.0000e+00 - val_loss: 0.4498
# Epoch 83/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4950 - val_accuracy: 0.0000e+00 - val_loss: 0.4598
# Epoch 84/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4958 - val_accuracy: 0.0000e+00 - val_loss: 0.4712
# Epoch 85/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4911 - val_accuracy: 0.0000e+00 - val_loss: 0.4601
# Epoch 86/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4900 - val_accuracy: 0.0000e+00 - val_loss: 0.4654
# Epoch 87/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4920 - val_accuracy: 0.0000e+00 - val_loss: 0.4763
# Epoch 88/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5315 - val_accuracy: 0.0000e+00 - val_loss: 0.4476
# Epoch 89/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4997 - val_accuracy: 0.0000e+00 - val_loss: 0.4584
# Epoch 90/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5068 - val_accuracy: 0.0000e+00 - val_loss: 0.4513
# Epoch 91/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5188 - val_accuracy: 0.0000e+00 - val_loss: 0.4504
# Epoch 92/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5015 - val_accuracy: 0.0000e+00 - val_loss: 0.4517
# Epoch 93/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4989 - val_accuracy: 0.0000e+00 - val_loss: 0.4534
# Epoch 94/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4891 - val_accuracy: 0.0000e+00 - val_loss: 0.4493
# Epoch 95/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5002 - val_accuracy: 0.0000e+00 - val_loss: 0.4601
# Epoch 96/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4921 - val_accuracy: 0.0000e+00 - val_loss: 0.4712
# Epoch 97/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5221 - val_accuracy: 0.0000e+00 - val_loss: 0.4983
# Epoch 98/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5171 - val_accuracy: 0.0000e+00 - val_loss: 0.4656
# Epoch 99/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5173 - val_accuracy: 0.0000e+00 - val_loss: 0.4642
# Epoch 100/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5147 - val_accuracy: 0.0000e+00 - val_loss: 0.4694
# Epoch 101/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5100 - val_accuracy: 0.0000e+00 - val_loss: 0.4664
# Epoch 102/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4973 - val_accuracy: 0.0000e+00 - val_loss: 0.4856
# Epoch 103/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5062 - val_accuracy: 0.0000e+00 - val_loss: 0.4637
# Epoch 104/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4928 - val_accuracy: 0.0000e+00 - val_loss: 0.4560
# Epoch 105/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4872 - val_accuracy: 0.0000e+00 - val_loss: 0.4639
# Epoch 106/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4954 - val_accuracy: 0.0000e+00 - val_loss: 0.4570
# Epoch 107/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4951 - val_accuracy: 0.0000e+00 - val_loss: 0.4642
# Epoch 108/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5035 - val_accuracy: 0.0000e+00 - val_loss: 0.4673
# Epoch 109/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5081 - val_accuracy: 0.0000e+00 - val_loss: 0.4715
# Epoch 110/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5087 - val_accuracy: 0.0000e+00 - val_loss: 0.4650
# Epoch 111/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4891 - val_accuracy: 0.0000e+00 - val_loss: 0.4607
# Epoch 112/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4866 - val_accuracy: 0.0000e+00 - val_loss: 0.4869
# Epoch 113/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5117 - val_accuracy: 0.0000e+00 - val_loss: 0.4686
# Epoch 114/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5079 - val_accuracy: 0.0000e+00 - val_loss: 0.4675
# Epoch 115/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4882 - val_accuracy: 0.0000e+00 - val_loss: 0.4610
# Epoch 116/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4838 - val_accuracy: 0.0000e+00 - val_loss: 0.4639
# Epoch 117/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4808 - val_accuracy: 0.0000e+00 - val_loss: 0.4757
# Epoch 118/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4806 - val_accuracy: 0.0000e+00 - val_loss: 0.4757
# Epoch 119/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.4827 - val_accuracy: 0.0000e+00 - val_loss: 0.4744
# Epoch 120/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4909 - val_accuracy: 0.0000e+00 - val_loss: 0.4696
# Epoch 121/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4853 - val_accuracy: 0.0000e+00 - val_loss: 0.4692
# Epoch 122/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4794 - val_accuracy: 0.0000e+00 - val_loss: 0.4711
# Epoch 123/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4863 - val_accuracy: 0.0000e+00 - val_loss: 0.4584
# Epoch 124/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4813 - val_accuracy: 0.0000e+00 - val_loss: 0.4744
# Epoch 125/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4793 - val_accuracy: 0.0000e+00 - val_loss: 0.4675
# Epoch 126/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4768 - val_accuracy: 0.0000e+00 - val_loss: 0.4797
# Epoch 127/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4756 - val_accuracy: 0.0000e+00 - val_loss: 0.4729
# Epoch 128/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4784 - val_accuracy: 0.0000e+00 - val_loss: 0.4942
# Epoch 129/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.4848 - val_accuracy: 0.0000e+00 - val_loss: 0.4870
# Epoch 130/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4951 - val_accuracy: 0.0000e+00 - val_loss: 0.4863
# Epoch 131/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4942 - val_accuracy: 0.0000e+00 - val_loss: 0.4822
# Epoch 132/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4858 - val_accuracy: 0.0000e+00 - val_loss: 0.4800
# Epoch 133/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4856 - val_accuracy: 0.0000e+00 - val_loss: 0.4696
# Epoch 134/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4819 - val_accuracy: 0.0000e+00 - val_loss: 0.4974
# Epoch 135/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4820 - val_accuracy: 0.0000e+00 - val_loss: 0.4624
# Epoch 136/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4787 - val_accuracy: 0.0000e+00 - val_loss: 0.4666
# Epoch 137/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4924 - val_accuracy: 0.0000e+00 - val_loss: 0.4805
# Epoch 138/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4911 - val_accuracy: 0.0000e+00 - val_loss: 0.4670
# Epoch 139/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4954 - val_accuracy: 0.0000e+00 - val_loss: 0.4667
# Epoch 140/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4874 - val_accuracy: 0.0000e+00 - val_loss: 0.4654
# Epoch 141/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4783 - val_accuracy: 0.0000e+00 - val_loss: 0.5199
# Epoch 142/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4909 - val_accuracy: 0.0000e+00 - val_loss: 0.4638
# Epoch 143/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4755 - val_accuracy: 0.0000e+00 - val_loss: 0.4759
# Epoch 144/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4706 - val_accuracy: 0.0000e+00 - val_loss: 0.4622
# Epoch 145/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4753 - val_accuracy: 0.0000e+00 - val_loss: 0.4848
# Epoch 146/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4790 - val_accuracy: 0.0000e+00 - val_loss: 0.5221
# Epoch 147/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5343 - val_accuracy: 0.0000e+00 - val_loss: 0.4498
# Epoch 148/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4948 - val_accuracy: 0.0000e+00 - val_loss: 0.4628
# Epoch 149/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4830 - val_accuracy: 0.0000e+00 - val_loss: 0.4896
# Epoch 150/150
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4869 - val_accuracy: 0.0000e+00 - val_loss: 0.4717

# %%
predictionsA = modelA.predict(x_test)
ages_A = predictionsA.flatten() * scaling_y
print("Model A predictions:", len(ages_A))
print("Test set size:", len(y_test))
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model A predictions: 1033
# Test set size: 1033

# %%
print("Training set size:", len(x_train))
print("Test set size:", len(x_test))
# Out:
# Training set size: 9311
# Test set size: 1033

# %%
metric = 0.3

goodfitA = np.where(((1 - metric) < predictionsA / y_test) & ((1 + metric) > predictionsA / y_test))
badfitA  = np.where(((1 - metric) > predictionsA / y_test) | ((1 + metric) < predictionsA / y_test))

print('With', neurons_per_layer_A, 'neurons per layer,', layers_A, 'layers, and', iterations_A, 'iterations')
print('using the training set', trainbin)
print(len(goodfitA[0]) / len(y_test) * 100, 'percent of the ages are good')
print(len(badfitA[0]) / len(y_test) * 100,  'percent of the ages are bad')
# Out:
# With 32 neurons per layer, 10 layers, and 150 iterations
# using the training set slice(0, -1035, None)
# 66.60212971926428 percent of the ages are good
# 33.39787028073572 percent of the ages are bad

# %%
plt.scatter(y_test.flatten() * scaling_y, predictionsA.flatten() * scaling_y, 
    s=0.1, c=(y_test.flatten() * scaling_y), cmap='inferno', alpha=0.8)
plt.xlim(0, 14)
plt.ylim(0, 14)
plt.plot([0, 14], [0, 14], 'k-', linewidth=2)
plt.plot([0, 14], [0, 14 * (1 + metric)], 'r--', linewidth=1)
plt.plot([0, 14], [0, 14 * (1 - metric)], 'r--', linewidth=1)
plt.xlabel('Seismic Age [Gyr]')
plt.ylabel('Predicted Age [Gyr]')
plt.title('Model A: Predicted vs. Seismic Age')
cbar = plt.colorbar()
cbar.set_label('Seismic Age [Gyr]')
plt.savefig("Task_12_ModelA_Predicted_vs_SeismicAge_ALL_Donley.png", dpi=600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# # Model B

# %%
neurons_per_layer_B = 64
layers_B = 5
iterations_B = 120

# %%
inputs = keras.Input(shape=(6,))
x = inputs
for i in range(layers_B):
    x = keras.layers.Dense(neurons_per_layer_B, activation='relu')(x)

outputs_B = keras.layers.Dense(1)(x)
modelB = keras.Model(inputs=inputs, outputs=outputs_B, name='modelB')
modelB.summary()
# Out:
# Model: "modelB"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,153 (67.00 KB)
#  Trainable params: 17,153 (67.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelB.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
x_train_B = x_train
y_train_B = y_train
x_test_B = x_test
y_test_B = y_test

# %%
modelB.fit(x_train_B, y_train_B, epochs=iterations_B, batch_size=300, validation_data=(x_test_B, y_test_B))
# Out:
# Epoch 1/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0000e+00 - loss: 0.8919 - val_accuracy: 0.0000e+00 - val_loss: 0.6291
# Epoch 2/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.6192 - val_accuracy: 0.0000e+00 - val_loss: 0.5011
# Epoch 3/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5679 - val_accuracy: 0.0000e+00 - val_loss: 0.4854
# Epoch 4/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5605 - val_accuracy: 0.0000e+00 - val_loss: 0.4936
# Epoch 5/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5616 - val_accuracy: 0.0000e+00 - val_loss: 0.5063
# Epoch 6/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5575 - val_accuracy: 0.0000e+00 - val_loss: 0.4914
# Epoch 7/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5474 - val_accuracy: 0.0000e+00 - val_loss: 0.4730
# Epoch 8/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5387 - val_accuracy: 0.0000e+00 - val_loss: 0.4832
# Epoch 9/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5541 - val_accuracy: 0.0000e+00 - val_loss: 0.4695
# Epoch 10/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5386 - val_accuracy: 0.0000e+00 - val_loss: 0.4661
# Epoch 11/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5329 - val_accuracy: 0.0000e+00 - val_loss: 0.4816
# Epoch 12/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5367 - val_accuracy: 0.0000e+00 - val_loss: 0.4698
# Epoch 13/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5335 - val_accuracy: 0.0000e+00 - val_loss: 0.4680
# Epoch 14/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5281 - val_accuracy: 0.0000e+00 - val_loss: 0.4769
# Epoch 15/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5308 - val_accuracy: 0.0000e+00 - val_loss: 0.4683
# Epoch 16/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5222 - val_accuracy: 0.0000e+00 - val_loss: 0.4708
# Epoch 17/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5208 - val_accuracy: 0.0000e+00 - val_loss: 0.4554
# Epoch 18/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5211 - val_accuracy: 0.0000e+00 - val_loss: 0.4511
# Epoch 19/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5275 - val_accuracy: 0.0000e+00 - val_loss: 0.4584
# Epoch 20/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5259 - val_accuracy: 0.0000e+00 - val_loss: 0.4528
# Epoch 21/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5203 - val_accuracy: 0.0000e+00 - val_loss: 0.4726
# Epoch 22/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5141 - val_accuracy: 0.0000e+00 - val_loss: 0.4698
# Epoch 23/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5247 - val_accuracy: 0.0000e+00 - val_loss: 0.4943
# Epoch 24/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5332 - val_accuracy: 0.0000e+00 - val_loss: 0.4719
# Epoch 25/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5233 - val_accuracy: 0.0000e+00 - val_loss: 0.4560
# Epoch 26/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5157 - val_accuracy: 0.0000e+00 - val_loss: 0.4514
# Epoch 27/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5103 - val_accuracy: 0.0000e+00 - val_loss: 0.4597
# Epoch 28/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5133 - val_accuracy: 0.0000e+00 - val_loss: 0.4513
# Epoch 29/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5088 - val_accuracy: 0.0000e+00 - val_loss: 0.4631
# Epoch 30/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5158 - val_accuracy: 0.0000e+00 - val_loss: 0.4569
# Epoch 31/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5099 - val_accuracy: 0.0000e+00 - val_loss: 0.4638
# Epoch 32/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5089 - val_accuracy: 0.0000e+00 - val_loss: 0.4524
# Epoch 33/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5044 - val_accuracy: 0.0000e+00 - val_loss: 0.4582
# Epoch 34/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5029 - val_accuracy: 0.0000e+00 - val_loss: 0.4520
# Epoch 35/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5035 - val_accuracy: 0.0000e+00 - val_loss: 0.4659
# Epoch 36/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5025 - val_accuracy: 0.0000e+00 - val_loss: 0.4462
# Epoch 37/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4993 - val_accuracy: 0.0000e+00 - val_loss: 0.4573
# Epoch 38/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5062 - val_accuracy: 0.0000e+00 - val_loss: 0.4473
# Epoch 39/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5043 - val_accuracy: 0.0000e+00 - val_loss: 0.4721
# Epoch 40/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5055 - val_accuracy: 0.0000e+00 - val_loss: 0.4582
# Epoch 41/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5007 - val_accuracy: 0.0000e+00 - val_loss: 0.4806
# Epoch 42/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5122 - val_accuracy: 0.0000e+00 - val_loss: 0.4581
# Epoch 43/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5044 - val_accuracy: 0.0000e+00 - val_loss: 0.4758
# Epoch 44/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5251 - val_accuracy: 0.0000e+00 - val_loss: 0.4572
# Epoch 45/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5204 - val_accuracy: 0.0000e+00 - val_loss: 0.4679
# Epoch 46/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5121 - val_accuracy: 0.0000e+00 - val_loss: 0.4498
# Epoch 47/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5064 - val_accuracy: 0.0000e+00 - val_loss: 0.4699
# Epoch 48/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5020 - val_accuracy: 0.0000e+00 - val_loss: 0.4568
# Epoch 49/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5141 - val_accuracy: 0.0000e+00 - val_loss: 0.4558
# Epoch 50/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5373 - val_accuracy: 0.0000e+00 - val_loss: 0.4552
# Epoch 51/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5128 - val_accuracy: 0.0000e+00 - val_loss: 0.4643
# Epoch 52/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5084 - val_accuracy: 0.0000e+00 - val_loss: 0.4599
# Epoch 53/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5108 - val_accuracy: 0.0000e+00 - val_loss: 0.4583
# Epoch 54/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4981 - val_accuracy: 0.0000e+00 - val_loss: 0.4622
# Epoch 55/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5032 - val_accuracy: 0.0000e+00 - val_loss: 0.4497
# Epoch 56/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4984 - val_accuracy: 0.0000e+00 - val_loss: 0.4627
# Epoch 57/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5065 - val_accuracy: 0.0000e+00 - val_loss: 0.4662
# Epoch 58/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4968 - val_accuracy: 0.0000e+00 - val_loss: 0.4622
# Epoch 59/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4940 - val_accuracy: 0.0000e+00 - val_loss: 0.4610
# Epoch 60/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4913 - val_accuracy: 0.0000e+00 - val_loss: 0.4851
# Epoch 61/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5296 - val_accuracy: 0.0000e+00 - val_loss: 0.4739
# Epoch 62/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5100 - val_accuracy: 0.0000e+00 - val_loss: 0.4792
# Epoch 63/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5046 - val_accuracy: 0.0000e+00 - val_loss: 0.4683
# Epoch 64/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5112 - val_accuracy: 0.0000e+00 - val_loss: 0.4676
# Epoch 65/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5330 - val_accuracy: 0.0000e+00 - val_loss: 0.4562
# Epoch 66/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5050 - val_accuracy: 0.0000e+00 - val_loss: 0.4676
# Epoch 67/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5021 - val_accuracy: 0.0000e+00 - val_loss: 0.4638
# Epoch 68/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5019 - val_accuracy: 0.0000e+00 - val_loss: 0.4599
# Epoch 69/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4980 - val_accuracy: 0.0000e+00 - val_loss: 0.4722
# Epoch 70/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4969 - val_accuracy: 0.0000e+00 - val_loss: 0.4658
# Epoch 71/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4927 - val_accuracy: 0.0000e+00 - val_loss: 0.4584
# Epoch 72/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4893 - val_accuracy: 0.0000e+00 - val_loss: 0.4570
# Epoch 73/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4892 - val_accuracy: 0.0000e+00 - val_loss: 0.4751
# Epoch 74/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5130 - val_accuracy: 0.0000e+00 - val_loss: 0.4750
# Epoch 75/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4950 - val_accuracy: 0.0000e+00 - val_loss: 0.4796
# Epoch 76/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4912 - val_accuracy: 0.0000e+00 - val_loss: 0.4859
# Epoch 77/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4911 - val_accuracy: 0.0000e+00 - val_loss: 0.4626
# Epoch 78/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4862 - val_accuracy: 0.0000e+00 - val_loss: 0.4699
# Epoch 79/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4932 - val_accuracy: 0.0000e+00 - val_loss: 0.4581
# Epoch 80/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4818 - val_accuracy: 0.0000e+00 - val_loss: 0.4801
# Epoch 81/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4887 - val_accuracy: 0.0000e+00 - val_loss: 0.4787
# Epoch 82/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4923 - val_accuracy: 0.0000e+00 - val_loss: 0.4609
# Epoch 83/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4828 - val_accuracy: 0.0000e+00 - val_loss: 0.4639
# Epoch 84/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4822 - val_accuracy: 0.0000e+00 - val_loss: 0.4816
# Epoch 85/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4888 - val_accuracy: 0.0000e+00 - val_loss: 0.4574
# Epoch 86/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4847 - val_accuracy: 0.0000e+00 - val_loss: 0.4738
# Epoch 87/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.4795 - val_accuracy: 0.0000e+00 - val_loss: 0.4756
# Epoch 88/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4800 - val_accuracy: 0.0000e+00 - val_loss: 0.4559
# Epoch 89/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4751 - val_accuracy: 0.0000e+00 - val_loss: 0.4761
# Epoch 90/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4806 - val_accuracy: 0.0000e+00 - val_loss: 0.4615
# Epoch 91/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4777 - val_accuracy: 0.0000e+00 - val_loss: 0.4876
# Epoch 92/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4771 - val_accuracy: 0.0000e+00 - val_loss: 0.4715
# Epoch 93/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4754 - val_accuracy: 0.0000e+00 - val_loss: 0.4740
# Epoch 94/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4743 - val_accuracy: 0.0000e+00 - val_loss: 0.4772
# Epoch 95/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4684 - val_accuracy: 0.0000e+00 - val_loss: 0.4734
# Epoch 96/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4728 - val_accuracy: 0.0000e+00 - val_loss: 0.4630
# Epoch 97/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4698 - val_accuracy: 0.0000e+00 - val_loss: 0.4716
# Epoch 98/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4745 - val_accuracy: 0.0000e+00 - val_loss: 0.4639
# Epoch 99/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4716 - val_accuracy: 0.0000e+00 - val_loss: 0.4757
# Epoch 100/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4741 - val_accuracy: 0.0000e+00 - val_loss: 0.4977
# Epoch 101/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4737 - val_accuracy: 0.0000e+00 - val_loss: 0.4935
# Epoch 102/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4913 - val_accuracy: 0.0000e+00 - val_loss: 0.4691
# Epoch 103/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4783 - val_accuracy: 0.0000e+00 - val_loss: 0.4987
# Epoch 104/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4796 - val_accuracy: 0.0000e+00 - val_loss: 0.4966
# Epoch 105/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4828 - val_accuracy: 0.0000e+00 - val_loss: 0.4924
# Epoch 106/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4729 - val_accuracy: 0.0000e+00 - val_loss: 0.4797
# Epoch 107/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4665 - val_accuracy: 0.0000e+00 - val_loss: 0.4758
# Epoch 108/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4693 - val_accuracy: 0.0000e+00 - val_loss: 0.5014
# Epoch 109/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5179 - val_accuracy: 0.0000e+00 - val_loss: 0.4797
# Epoch 110/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5294 - val_accuracy: 0.0000e+00 - val_loss: 0.4689
# Epoch 111/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5060 - val_accuracy: 0.0000e+00 - val_loss: 0.4605
# Epoch 112/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4772 - val_accuracy: 0.0000e+00 - val_loss: 0.5073
# Epoch 113/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5449 - val_accuracy: 0.0000e+00 - val_loss: 0.4910
# Epoch 114/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4981 - val_accuracy: 0.0000e+00 - val_loss: 0.4705
# Epoch 115/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4858 - val_accuracy: 0.0000e+00 - val_loss: 0.4732
# Epoch 116/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4854 - val_accuracy: 0.0000e+00 - val_loss: 0.4766
# Epoch 117/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4809 - val_accuracy: 0.0000e+00 - val_loss: 0.4771
# Epoch 118/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4755 - val_accuracy: 0.0000e+00 - val_loss: 0.4965
# Epoch 119/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4757 - val_accuracy: 0.0000e+00 - val_loss: 0.4856
# Epoch 120/120
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.4754 - val_accuracy: 0.0000e+00 - val_loss: 0.4770

# %%
predictionsB = modelB.predict(x_test_B)
predictionsB = predictionsB.flatten()
trueB = y_test_B.flatten()
print(len(predictionsB))
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1033

# %%
metric = 0.3

goodfitB = np.where( ((1 - metric) < predictionsB / trueB) & ((1 + metric) > predictionsB / trueB) )
badfitB  = np.where( ((1 - metric) > predictionsB / trueB) | ((1 + metric) < predictionsB / trueB) )

print('With', neurons_per_layer_B, 'neurons per layer,', layers_B, 'layers, and', iterations_B, 'iterations')
print('using the training set', trainbin)
print(len(goodfitB[0]) / len(trueB) * 100, 'percent of the ages are good')
print(len(badfitB[0]) / len(trueB) * 100, 'percent of the ages are bad')
# Out:
# With 64 neurons per layer, 5 layers, and 120 iterations
# using the training set slice(0, -1035, None)
# 66.02129719264279 percent of the ages are good
# 33.978702807357216 percent of the ages are bad

# %%
plt.scatter(trueB * scaling_y, predictionsB.flatten() * scaling_y, 
    s=0.1, c=(trueB * scaling_y), cmap='inferno', alpha=0.8)
plt.xlim(0, 14)
plt.ylim(0, 14)
plt.plot([0, 14], [0, 14], 'k-', linewidth=2)
plt.plot([0, 14], [0, 14 * (1 + metric)], 'r--', linewidth=1)
plt.plot([0, 14], [0, 14 * (1 - metric)], 'r--', linewidth=1)
plt.xlabel('Seismic Age [Gyr]')
plt.ylabel('Predicted Age [Gyr]')
plt.title('Model B: Predicted vs. Seismic Age')
cbar = plt.colorbar()
cbar.set_label('Seismic Age [Gyr]')
plt.savefig("Task_12_ModelB_Predicted_vs_SeismicAge_ALL_Donley.png", dpi=600, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
print("Model A ages min/max:", predictionsA.min(), predictionsA.max())
print("Model B ages min/max:", predictionsB.min(), predictionsB.max())
# Out:
# Model A ages min/max: 0.17486826 4.807913
# Model B ages min/max: 0.19229695 6.7587934

# %%
print("Model A ages min/max:",
      (predictionsA.flatten() * scaling_y).min(),
      (predictionsA.flatten() * scaling_y).max())

print("Model B ages min/max:",
      (predictionsB.flatten() * scaling_y).min(),
      (predictionsB.flatten() * scaling_y).max())
# Out:
# Model A ages min/max: 0.8716920251920819 23.966724253368376
# Model B ages min/max: 0.9585714612230658 33.6915710508585

# %%
test_ids = apokasc3_matched['KIC'][testing]
print("Number of KIC IDs set:", len(test_ids))
# Out:
# Number of KIC IDs set: 1033

# %%
true_age = y_test.flatten() * scaling_y
ageA = predictionsA.flatten() * scaling_y
ageB = predictionsB.flatten() * scaling_y

# %%
print(len(test_ids), len(true_age), len(ageA), len(ageB))
# Out:
# 1033 1033 1033 1033

# %%
import pandas as pd
results_table = pd.DataFrame({
    'KIC': test_ids,
    'Seismic_Age_Gyr': true_age,
    'Pred_Age_A_Gyr': ageA,
    'Pred_Age_B_Gyr': ageB,
    'Difference_B_minus_A': ageB - ageA})
print("Results table size:", len(results_table))
results_table.head()
# Out:
# Results table size: 1033
#         KIC  Seismic_Age_Gyr  Pred_Age_A_Gyr  Pred_Age_B_Gyr  \
# 0  11403437          12.3847        9.203126        9.911847
# 1  11403541           4.3850        1.919929        1.976728
# 2  11403918           5.4317        5.602170        5.875329
# 3  11404916           7.3456        5.198683        5.913728
# 4  11404925           0.9791        3.028524        1.884917
#
#    Difference_B_minus_A
# 0              0.708720
# 1              0.056799
# 2              0.273160
# 3              0.715045
# 4             -1.143608

# %%
diff = results_table['Difference_B_minus_A']
mean_diff = np.mean(diff)
mean_abs_diff = np.mean(np.abs(diff))
rms_diff = np.sqrt(np.mean(diff**2))
print("Mean difference (B - A):", mean_diff)
print("Mean absolute difference:", mean_abs_diff)
print("RMS difference:", rms_diff)
# Out:
# Mean difference (B - A): 0.1732135296979297
# Mean absolute difference: 0.4918900695354128
# RMS difference: 0.7581341254984061

# %%
results_table.to_csv("Task_12_APOKASC3_Age_Comparison_Donley.csv", index=False)
print("Saved file: Task_12_APOKASC3_Age_Comparison_Donley.csv")
# Out:
# Saved file: Task_12_APOKASC3_Age_Comparison_Donley.csv

# %%
std_diff = np.std(diff)
print("Average difference (B - A):", avg_diff)
print("Standard deviation:", std_diff)
# Out:
# Average difference (B - A): 0.5943736807590078
# Standard deviation: 0.738081584497823

# %%
plt.hist(results_table['Difference_B_minus_A'], bins=30, color='grey', alpha=0.8)
plt.xlabel("Model B - Model A (Gyr)")
plt.ylabel("Number of Stars")
plt.title("Distribution of Age Differences Between Networks")
plt.savefig("Task_12_AgeDifference_Distribution_Donley.png", dpi=600, bbox_inches='tight', pad_inches=0.1)
plt.show()
