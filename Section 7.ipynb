# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import astropy.coordinates as coord
import astropy.units as u
from astropy.io import fits, ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord
import pandas as pd
import matplotlib.ticker as ticker
from matplotlib.colors import Normalize
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from tensorflow import keras

plt.rcParams['font.family'] = 'sans-serif' 
plt.rcParams['font.sans-serif'] = ['Arial']

plt.rcParams['axes.titlesize'] = 14  # font size for plot titles
plt.rcParams['axes.labelsize'] = 12  # font size for x and y axis labels
plt.rcParams['xtick.labelsize'] = 10 # font size for x-axis tick labels
plt.rcParams['ytick.labelsize'] = 10 # font size for y-axis tick labels
plt.rcParams['legend.fontsize'] = 10 # font size for legend

# %%
filename=f'{os.getcwd()}\\astraAllStarASPCAP-0.6.0.fits\\astraAllStarASPCAP-0.6.0.fits'
tb = fits.open(filename)
header=tb[2].header
data = tb[2].data

# %%
# get rid of stars with negative distances
mask_gaia = (data['zgr_plx']>0)

# use skycoord to input information, correct units
c = SkyCoord(ra=data['ra'][mask_gaia]*u.deg, dec=data['dec'][mask_gaia]*u.deg, 
             distance=(data['r_med_geo'][mask_gaia])*u.pc,
             pm_ra_cosdec=data['pmra'][mask_gaia]*u.mas/u.yr, 
             pm_dec=data['pmde'][mask_gaia]*u.mas/u.yr,
            radial_velocity=data['v_rad'][mask_gaia]*u.km/u.s) 

# transform to galactocentric coordinate
# the assumed values are from Schonrich et al 2010, and from Gravity collab 2022
galcen = c.transform_to(coord.Galactocentric(galcen_v_sun=[8, 254, 8] * u.km / u.s, galcen_distance=8.275 * u.kpc))

# %%
# Extract the galactic coordinates and motions
x = galcen.x.value
y = galcen.y.value
z = galcen.z.value

vx = galcen.v_x.value
vy = galcen.v_y.value
vz = galcen.v_z.value

#galactocentric radius (either in the disk-R or distance from the galactic center)
R = np.sqrt(x**2+y**2)
rgal = np.sqrt(x**2+y**2+z**2)

# %%
#I clipped data table, including the the M/H and alpha/M vectors to the same length as the R and z information first before plotting
data_masked=data[mask_gaia]

# %%
R_kpc = R/1000
z_kpc = z/1000
r_gal_kpc = rgal/1000

# %%
# Age option 1 TESS data Theodoridis et al. 2025
#Reading in the table, making sure all the tables have a column named Age in Gyr
# and that every star in the table has an Age
tessraw = Table.read("Theodoridis2025.csv", format="ascii")
#this one has an age column in Gyr already so we're just going to rename it Age
tessraw['Final_age'].name='Age'
hasagetess=np.where((tessraw['Age']==tessraw['Age']) & (tessraw['Age']>0.1) &(tessraw['Flag']==0))
tess=tessraw[hasagetess]
tess
# Out:
# <Table length=124340>
#    TIC    Star_type        Age         ...      Teff_diff       Flag
#   int64      str5        float64       ...       float64       int64
# --------- --------- ------------------ ... ------------------- -----
# 347020604     Clump  4.933697638292032 ...  174.04556888801108     0
# 365250045       RGB  5.919390103924665 ...   97.59468645767902     0
# 377058143       RGB 10.659761236332615 ...  -113.8047440968976     0
# 347548024       RGB 4.2433496208314345 ...  -141.2146776884456     0
# 328321210     Clump  5.297976079237009 ...   219.9442341489521     0
# 328321103       RGB   3.76901613056093 ...  -49.01280965939077     0
# 328324062     Clump  2.303632505100647 ...    224.565928540389     0
# 328400618     Clump  2.159728298323744 ...  132.08513858645256     0
# 328255103     Clump  6.418514994888695 ...  199.00344572811537     0
#       ...       ...                ... ...                 ...   ...
#  24293754     Clump  7.270499767640112 ...   100.7095877557831     0
# 444151014       RGB 1.3293989221533338 ...    5.87378596065173     0
# 439387397       RGB 10.886531443589943 ... -19.501883450057903     0
# 439387373       RGB 13.559665913368113 ...  -82.24621400531942     0
# 415686794     Clump 3.5268592139224655 ...  265.21086792035476     0
#  99837810     Clump 11.042183147979149 ...  174.07698216540484     0
#  99821552       RGB 2.1627981000040437 ... -109.79588133983816     0
# 441029961     Clump  4.068854769155727 ...  118.59480020653608     0
# 441015317       RGB        10.13177954 ...  -18.31305666275875     0
#  99818843       RGB  6.006672813122813 ... -155.28605255012826     0

# %%
agedata = tess

# %%
# Option 1 TESS Theodoridis et al. 2025
intersect, ind_a, ind_b = np.intersect1d(data_masked['tic_v8_id'], agedata['TIC'], return_indices=True)
print(len(ind_b))
# Out:
# 16132

# %%
agedata[ind_b]
# Out:
# <Table length=16132>
#    TIC    Star_type        Age         ...      Teff_diff       Flag
#   int64      str5        float64       ...       float64       int64
# --------- --------- ------------------ ... ------------------- -----
#    816261     Clump 1.8023030918124707 ...  132.17833018556848     0
#    816406       RGB 1.0483588590152084 ... -13.292490129164436     0
#    858558     Clump  2.574277954846038 ...   233.1577303434542     0
#    858755     Clump  2.764406010747628 ...  153.07873060647034     0
#    859100     Clump 6.6001432109618206 ...  115.34317349770754     0
#    862643       RGB  7.605498315111465 ...   52.84072335573546     0
#    862777       RGB 0.5198575922620129 ... -13.402103872283078     0
#    862901     Clump  4.994844984058082 ...  118.23265652622558     0
#    864979       RGB  3.332326720168662 ...   58.75670475494098     0
#       ...       ...                ... ...                 ...   ...
# 470652261       RGB  4.517305566117317 ...   46.89672924979095     0
# 470676723       RGB  5.681298612787401 ... -0.9914177150321848     0
# 470677522     Clump  4.850370108081497 ...   330.1203021140773     0
# 470677857     Clump  9.391440748860184 ...  218.85865360788463     0
# 470678683     Clump  2.534158613997241 ...  197.89806254034735     0
# 470678733     Clump  7.548307426744003 ...  185.61651213844925     0
# 470680098       RGB 2.2296573035077754 ...   50.02345242729552     0
# 470917347       RGB  5.124696632660715 ...  -71.85033191262028     0
# 470951227     Clump  9.766313823700846 ...  232.60485018124473     0
# 470979810     Clump   2.51676636039625 ...  128.77133721169776     0

# %%
fullx = np.dstack([data_masked['teff'][ind_a],data_masked['logg'][ind_a], data_masked['m_h_atm'][ind_a],
                   data_masked['alpha_m_atm'][ind_a], data_masked['c_h'][ind_a], data_masked['n_h'][ind_a]])[0]

fully = np.dstack([agedata['Age'][ind_b]])[0] #for Pinsonneault 2018

#remove non-finite entries!
mask = np.all(np.isfinite(fullx), axis=1) & np.all(np.isfinite(fully), axis=1)
fullx, fully = fullx[mask], fully[mask]

scaling_x = np.median(fullx, axis=0)
scaling_y = np.median(fully, axis=0)

fullx, fully = fullx/scaling_x, fully/scaling_y

# %%
#pick some numbers
neurons_per_layer=12
layers=3
iterations=100

# %%
#start with an input layer
inputs = keras.Input(shape=(6,))
#now we add the Dense layers (indicating the previous layer in the brackets following the layer declaration

#change this part if you're changing the number of layers
layer1 = keras.layers.Dense(neurons_per_layer, activation='relu')(inputs)
layer2 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer1)
layer3 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer2)
layer4 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer3)
layer5 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer4)
layer6 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer5)
layer7 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer6)
layer8 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer7)
layer9 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer8)
layer10 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer9)
layer11 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer10)
layer12 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer11)
layer13 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer12)
layer14 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer13)
layer15 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer14)
layer16 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer15)
layer17 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer16)
layer18 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer17)
layer19 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer18)
layer20 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer19)
layer21 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer20)
layer22 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer21)
layer23 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer22)
layer24 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer23)
layer25 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer24)
layer26 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer25)
layer27 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer26)
layer28 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer27)
layer29 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer28)
layer30 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer29)
layer31 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer30)
layer32 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer31)
layer33 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer32)
layer34 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer33)
layer35 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer34)
layer36 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer35)
layer37 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer36)
layer38 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer37)
layer39 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer38)
layer40 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer39)
layer41 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer40)
layer42 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer41)
layer43 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer42)
layer44 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer43)
layer45 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer44)
layer46 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer45)
layer47 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer46)
layer48 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer47)
layer49 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer48)
layer50 = keras.layers.Dense(neurons_per_layer, activation='relu')(layer49)

#then the output layer YOU ALSO HAVE TO MAKE THIS MATCH YOUR NUMBER OF LAYERS
outputs = keras.layers.Dense(1)(layer50)


# then we put that all together in the Model object
model = keras.Model(inputs=inputs, outputs=outputs, name='test')
#and we can print a summary to check it all went to plan
model.summary()
# Out:
# Model: "test"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 12)             │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_80 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_81 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_84 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_85 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_86 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_89 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_90 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_91 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_93 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_97 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_100 (Dense)               │ (None, 12)             │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,741 (30.24 KB)
#  Trainable params: 7,741 (30.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
tenpercent=len(agedata['Age'][ind_b])//10 #figure out what ten percent of this set of age data is

#last name before M 
trainbin=slice(0,-1*tenpercent-1)
testing=slice(-1*tenpercent,-1)

x_train, y_train = fullx[trainbin], fully[trainbin]
x_test, y_test = fullx[testing], fully[testing]

# %% [markdown]
# Okay now train the neural network

# %%
model.fit(x_train, y_train, epochs=iterations, validation_split=0.05, batch_size=300)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - accuracy: 0.0000e+00 - loss: 1.3725 - val_accuracy: 0.0000e+00 - val_loss: 1.0598
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.7381 - val_accuracy: 0.0000e+00 - val_loss: 0.3316
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3498 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2991
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2992
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2976
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2987
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2983
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2984
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.3031
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3441 - val_accuracy: 0.0000e+00 - val_loss: 0.2984
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2983
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2973
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2973
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2977
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.3022
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2990
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2983
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2973
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2978
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.3026
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3442 - val_accuracy: 0.0000e+00 - val_loss: 0.2979
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2974
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2986
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2978
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3439 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2971
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2976
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2997
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.3004
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2978
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2974
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.2973
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3441 - val_accuracy: 0.0000e+00 - val_loss: 0.2987
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.2971
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2982
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2991
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2971
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2992
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2977
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2979
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2993
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3441 - val_accuracy: 0.0000e+00 - val_loss: 0.3004
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2990
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3442 - val_accuracy: 0.0000e+00 - val_loss: 0.2990
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3442 - val_accuracy: 0.0000e+00 - val_loss: 0.2993
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2987
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2987
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3441 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 66/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 67/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.3006
# Epoch 68/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2975
# Epoch 69/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 70/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2987
# Epoch 71/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 72/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 73/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2984
# Epoch 74/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2984
# Epoch 75/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2981
# Epoch 76/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2977
# Epoch 77/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2985
# Epoch 78/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 79/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3439 - val_accuracy: 0.0000e+00 - val_loss: 0.2971
# Epoch 80/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2978
# Epoch 81/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 82/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2980
# Epoch 83/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2985
# Epoch 84/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.2979
# Epoch 85/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2982
# Epoch 86/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 87/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2970
# Epoch 88/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2974
# Epoch 89/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2996
# Epoch 90/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3436 - val_accuracy: 0.0000e+00 - val_loss: 0.2976
# Epoch 91/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.3023
# Epoch 92/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2976
# Epoch 93/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3438 - val_accuracy: 0.0000e+00 - val_loss: 0.2990
# Epoch 94/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.2992
# Epoch 95/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 96/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.2978
# Epoch 97/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3433 - val_accuracy: 0.0000e+00 - val_loss: 0.2991
# Epoch 98/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3434 - val_accuracy: 0.0000e+00 - val_loss: 0.2972
# Epoch 99/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2994
# Epoch 100/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.3435 - val_accuracy: 0.0000e+00 - val_loss: 0.2973

# %%
DR19x = np.dstack([data_masked['teff'],data_masked['logg'], data_masked['m_h_atm'],
                   data_masked['alpha_m_atm'], data_masked['c_h'], data_masked['n_h']])[0]
print(len(data_masked['teff']))

DR19x= DR19x/scaling_x

predictionsDR19 = model.predict(DR19x)
# Out:
# 963539
# 30111/30111 ━━━━━━━━━━━━━━━━━━━━ 73s 2ms/step

# %% [markdown]
# ## Section 7: Paper Tasks

# %% [markdown]
# __Task #32:__ Fig 2. Four panels for the full DR19 dataset: alpha/fe vs fe/h, Z vs R gal, alpha/M vs C/N, and logg vs teff, all color coded by something sensible

# %%
DR19_pd = pd.DataFrame({
    '[α/Fe]': (data_masked['alpha_m_atm']-data_masked['fe_h']).astype('float32'),
    '[Fe/H]': data_masked['fe_h'].astype('float32'),
    'Z (kpc)': z_kpc,
    'R_gal (kpc)': r_gal_kpc,
    '[α/M]': data_masked['alpha_m_atm'].astype('float32'),
    '[C/N]': (data_masked['c_h']-data_masked['n_h']).astype('float32'),
    'Log_g': data_masked['logg'].astype('float32'),
    'T_eff': data_masked['teff'].astype('float32'),
    'Predicted_age': predictionsDR19.ravel()
})
DR19_pd
# Out:
#           [α/Fe]    [Fe/H]   Z (kpc)  R_gal (kpc)     [α/M]     [C/N]  \
# 0      -0.086501  0.036716 -0.042422     8.003237 -0.049785 -0.320997
# 1      -0.134628  0.082482 -0.045911     8.000944 -0.052146 -0.319170
# 2      -0.151757  0.051216 -0.048636     7.994735 -0.100541 -0.749890
# 3      -0.206624  0.152679 -0.046894     8.008039 -0.053945 -0.408940
# 4       0.197169 -0.193401  0.684357    10.230661  0.003768       NaN
# ...          ...       ...       ...          ...       ...       ...
# 963534  0.511827 -0.466151  1.143305     9.525971  0.045676 -0.061100
# 963535       NaN       NaN -2.278966     5.654070       NaN       NaN
# 963536 -0.451189  0.359463 -0.192352     7.764072 -0.091726 -1.899260
# 963537 -0.103436  0.080672 -0.319612     8.006440 -0.022764 -0.204084
# 963538  0.176210 -0.163557 -0.009309     8.249973  0.012653 -0.101054
#
#            Log_g        T_eff  Predicted_age
# 0       2.561960  4521.324707       1.076813
# 1       2.574178  4745.399902       1.076813
# 2       2.396280  4687.408691       1.076813
# 3       2.595649  4726.982910       1.076813
# 4       0.736285  3542.665527       1.076813
# ...          ...          ...            ...
# 963534  2.090511  4585.859375       1.076813
# 963535       NaN          NaN       1.076813
# 963536  3.563128  6210.836426       1.076813
# 963537  3.376096  4855.964844       1.076813
# 963538  4.558627  4480.262207       1.076813
#
# [963539 rows x 9 columns]

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,20)) # rows, columns

# Top-left panel
cmap_1 = plt.cm.coolwarm
cmap_1.set_under('white')
DR19_pd_no_nan = DR19_pd.dropna(subset=['[Fe/H]', '[α/Fe]'])

ax[0,0].scatter(DR19_pd['[Fe/H]'], DR19_pd['[α/Fe]'], s=0.2, color='grey')
hist, xedges, yedges, plot_1 = ax[0, 0].hist2d(DR19_pd_no_nan['[Fe/H]'], DR19_pd_no_nan['[α/Fe]'], bins=300, cmap=cmap_1, alpha=0.5, vmin=1e-5)
cbar_1 = fig.colorbar(plot_1, ax=ax[0,0])
cbar_1.set_label('Number of Stars per bin (300x300)', fontsize=12)
ax[0,0].set_aspect(0.5)
ax[0,0].tick_params(axis='both', direction='in', length=6, which='major', right=True, top=True)
ax[0,0].tick_params(axis='both', direction='in', length=3, which='minor', right=True, top=True)
ax[0,0].xaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[0,0].xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax[0,0].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[0,0].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
# ax[0,0].text(0.5, 0.93, f'Insert Text', ha='center', va='center', fontsize=12, transform=ax[0,0].transAxes)
ax[0,0].set_ylabel('[α/Fe]', fontsize=12)
ax[0,0].set_xlabel('[Fe/H]', fontsize=12)
ax[0,0].set_title('[α/Fe] vs. [Fe/H]', fontsize=12)

# Top-right panel
plot_2 = ax[0,1].scatter(DR19_pd['R_gal (kpc)'], DR19_pd['Z (kpc)'], s=0.1, c=DR19_pd['[α/M]'], vmin=-0.5, vmax=0.5)
cbar_2 = fig.colorbar(plot_2, ax=ax[0,1])
cbar_2.set_label('[α/M]', fontsize=12)
ax[0,1].set_aspect(2)
ax[0,1].tick_params(axis='both', direction='in', length=6, which='major', right=True, top=True)
ax[0,1].tick_params(axis='both', direction='in', length=3, which='minor', right=True, top=True)
ax[0,1].xaxis.set_major_locator(ticker.MultipleLocator(1))
ax[0,1].xaxis.set_minor_locator(ticker.MultipleLocator(0.5))
ax[0,1].yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax[0,1].yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
# ax[0,1].text(0.5, 0.93, f'Insert Text', ha='center', va='center', fontsize=12, transform=ax[0,1].transAxes)
ax[0,1].set_xlim(0, 16)
ax[0,1].set_ylim(-4, 4)
ax[0,1].set_ylabel('$Z$ [kpc]', fontsize=12)
ax[0,1].set_xlabel('$R_{gal}$ [kpc]', fontsize=12)
ax[0,1].set_title('$Z$ vs. $R_{gal}$', fontsize=12)

# Bottom-left panel
plot_3 = ax[1,0].scatter(DR19_pd['[C/N]'], DR19_pd['[α/M]'], s=0.1, c=DR19_pd['Predicted_age']*scaling_y, vmin=(DR19_pd['Predicted_age']*scaling_y).min(), vmax=16)
cbar_3 = fig.colorbar(plot_3, ax=ax[1,0])
cbar_3.set_label('Predicted age [Gyr]', fontsize=12)
# ax[1,0].set_aspect(2)
ax[1,0].tick_params(axis='both', direction='in', length=6, which='major', right=True, top=True)
ax[1,0].tick_params(axis='both', direction='in', length=3, which='minor', right=True, top=True)
ax[1,0].xaxis.set_major_locator(ticker.MultipleLocator(1))
ax[1,0].xaxis.set_minor_locator(ticker.MultipleLocator(0.2))
ax[1,0].yaxis.set_major_locator(ticker.MultipleLocator(0.25))
ax[1,0].yaxis.set_minor_locator(ticker.MultipleLocator(0.05))
# ax[1,0].text(0.5, 0.93, f'Insert Text', ha='center', va='center', fontsize=12, transform=ax[1,0].transAxes)
ax[1,0].set_ylabel('[α/M]', fontsize=12)
ax[1,0].set_xlabel('[C/N]', fontsize=12)
ax[1,0].set_title('[α/M] vs. [C/N]', fontsize=12)

# Bottom-right panel
plot_4 = ax[1,1].scatter(DR19_pd['T_eff'], DR19_pd['Log_g'], s=0.1, c=DR19_pd['[Fe/H]'], vmin=DR19_pd['[Fe/H]'].min(), vmax=DR19_pd['[Fe/H]'].max())
cbar_4 = fig.colorbar(plot_4, ax=ax[1,1])
cbar_4.set_label('[Fe/H]', fontsize=12)
ax[1,1].set_aspect(500)
ax[1,1].tick_params(axis='both', direction='in', length=6, which='major', right=True, top=True)
ax[1,1].tick_params(axis='both', direction='in', length=3, which='minor', right=True, top=True)
ax[1,1].xaxis.set_major_locator(ticker.MultipleLocator(500))
ax[1,1].xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax[1,1].yaxis.set_major_locator(ticker.MultipleLocator(1))
ax[1,1].yaxis.set_minor_locator(ticker.MultipleLocator(0.2))
# ax[1,1].text(0.5, 0.93, f'Insert Text', ha='center', va='center', fontsize=12, transform=ax[1,1].transAxes)
ax[1,1].set_ylim(6, -1)
ax[1,1].set_xlim(7000, 3000)

ax[1,1].set_ylabel('log ($g$)', fontsize=12)
ax[1,1].set_xlabel('$T_{eff}$', fontsize=12)
ax[1,1].set_title('log ($g$) vs. $T_{eff}$', fontsize=12)

plt.subplots_adjust(wspace=0.1, hspace=0.3)
plt.suptitle('SDSS Data Release 19', fontsize=16)
plt.show()
